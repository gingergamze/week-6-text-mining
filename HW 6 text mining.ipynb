# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import MultinomialNB

# %%
#Explain briefly in your own words how the bag-of-words model and Naïve Bayes work, and how they work together.

#In the bag-of-words model: It is not matter, the order and position do. where the frequency of or occurrence of each word is used as a feature for training a classifier 
#however in the Naive Bayes model everything is based on probability that's why it is known as probabilistic classifiers

#They could be both work together as well because each of them has different function and study area. 
#I like this question that's why A short quiz in kahoot for us to examine our knowledge might be enjoyable

#I'm not sure about the last step in the assignment

# %%
df = pd.read_csv('Assignment text mining - data clothing reviews.csv')
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# ...

# %%
df["Class Name"].where(df["Class Name"]=="Dresses").dropna()
# Out:
# 1        Dresses
# 2        Dresses
# 5        Dresses
# 8        Dresses
# 9        Dresses
#           ...
# 23478    Dresses
# 23481    Dresses
# 23483    Dresses
# 23484    Dresses
# 23485    Dresses
# Name: Class Name, Length: 6319, dtype: object

# %%
df = pd.read_csv('Assignment text mining - data clothing reviews.csv')
df = df.loc[(df['Class Name'] == 'Dresses') | (df['Class Name'] == 'Intimates')]
text = df['Review Text'].values.astype('U') #Taking the text from the df. We need to convert it to Unicode
vect = CountVectorizer(stop_words='english') #Create the CV object, with English stop words
vect = vect.fit(text) #We fit the model with the words from the review text
docu_feat = vect.transform(text) # make a matrix
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 5           5         1080   49  Not for the very petite
# 8           8         1077   24               Flattering
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 5  I love tracy reese dresses, but this one is no...       2                0
# 8  I love this dress. i usually get an xs but it ...       5                1
#
#    Positive Feedback Count Division Name Department Name Class Name
# 0                        0     Initmates        Intimate  Intimates
# ...

# %%
df["Class Name"].where(df["Class Name"]=="Dresses").dropna().index
# Out:
# Int64Index([    1,     2,     5,     8,     9,    10,    11,    12,    14,
#                19,
#             ...
#             23470, 23473, 23474, 23475, 23477, 23478, 23481, 23483, 23484,
#             23485],
#            dtype='int64', length=6319)

# %%
# filter out all non-dress reviews
Nondress=df["Class Name"].where(df["Class Name"]!="Dresses").dropna().index

# %%
df.drop(Nondress) #with this code, index numbers of the nondress row are cleaned from the data
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 1               1         1080   34
# 2               2         1077   60
# 5               5         1080   49
# 8               8         1077   24
# 9               9         1077   34
# ...           ...          ...  ...
# 23478       23478         1104   32
# 23481       23481         1104   34
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 1                                                    NaN
# 2                                Some major design flaws
# 5                                Not for the very petite
# 8                                             Flattering
# 9                                      Such a fun dress!
# ...                                                  ...
# 23478                                       Unflattering
# 23481                     Great dress for many occasions
# ...

# %%
newdf = df.drop(Nondress).reset_index(drop=True) # to make the new df

# %%
newdf.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           1         1080   34                      NaN
# 1           2         1077   60  Some major design flaws
# 2           5         1080   49  Not for the very petite
# 3           8         1077   24               Flattering
# 4           9         1077   34        Such a fun dress!
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Love this dress!  it's sooo pretty.  i happene...       5                1
# 1  I had such high hopes for this dress and reall...       3                0
# 2  I love tracy reese dresses, but this one is no...       2                0
# 3  I love this dress. i usually get an xs but it ...       5                1
# 4  I'm 5"5' and 125 lbs. i ordered the s petite t...       5                1
#
#    Positive Feedback Count Division Name Department Name Class Name
# 0                        4       General         Dresses    Dresses
# ...

# %%
data = newdf.loc[:,["Review Text","Class Name", "Rating"]]
data
# Out:
#                                             Review Text Class Name  Rating
# 0     Love this dress!  it's sooo pretty.  i happene...    Dresses       5
# 1     I had such high hopes for this dress and reall...    Dresses       3
# 2     I love tracy reese dresses, but this one is no...    Dresses       2
# 3     I love this dress. i usually get an xs but it ...    Dresses       5
# 4     I'm 5"5' and 125 lbs. i ordered the s petite t...    Dresses       5
# ...                                                 ...        ...     ...
# 6314  I was surprised at the positive reviews for th...    Dresses       1
# 6315  I was very happy to snag this dress at such a ...    Dresses       5
# 6316  This fit well, but the top was very see throug...    Dresses       3
# 6317  I bought this dress for a wedding i have this ...    Dresses       3
# 6318  This dress in a lovely platinum is feminine an...    Dresses       5
#
# [6319 rows x 3 columns]

# %%
# to train a Naïve Bayes classifier predicting whether a review is positive (>3 stars) 
#or neutral/negative (<4 stars), I have to create a function for it

def rating(x):
    if(x > 3):
        return "positive"
    elif(x<3):
        return "negative"
    else:
        return "neutral"

# %%
data["Rating"] = data["Rating"].apply(rating)

# %%
data #after the rating function, I can see the rating in 3 kategory
# Out:
#                                             Review Text Class Name    Rating
# 0     Love this dress!  it's sooo pretty.  i happene...    Dresses  positive
# 1     I had such high hopes for this dress and reall...    Dresses   neutral
# 2     I love tracy reese dresses, but this one is no...    Dresses  negative
# 3     I love this dress. i usually get an xs but it ...    Dresses  positive
# 4     I'm 5"5' and 125 lbs. i ordered the s petite t...    Dresses  positive
# ...                                                 ...        ...       ...
# 6314  I was surprised at the positive reviews for th...    Dresses  negative
# 6315  I was very happy to snag this dress at such a ...    Dresses  positive
# 6316  This fit well, but the top was very see throug...    Dresses   neutral
# 6317  I bought this dress for a wedding i have this ...    Dresses   neutral
# 6318  This dress in a lovely platinum is feminine an...    Dresses  positive
#
# [6319 rows x 3 columns]

# %%
#a document-feature matrix

df = pd.read_csv('Assignment text mining - data clothing reviews.csv')
text = df['Review Text'].values.astype('U') #Taking the text from the df. We need to convert it to Unicode
vect = CountVectorizer(stop_words='english') #Create the CV object, with English stop words
vect = vect.fit(text) #We fit the model with the words from the review text
docu_feat = vect.transform(text) # make a matrix
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# ...

# %%
#Split the file into a training and a test set

nb = MultinomialNB() #create the model
X = docu_feat #the document-feature matrix is the X matrix
y = df['Rating'] #creating the y vector

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) #split the data and store it

nb = nb.fit(X_train, y_train) #fit the model X=features, y=character

#Evaluate the model
y_test_p = nb.predict(X_test)
nb.score(X_test, y_test)
# Out:
# 0.6196423502696565

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_test_p))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.43      0.03      0.06       267
#            2       0.29      0.08      0.12       456
#            3       0.38      0.37      0.38       892
#            4       0.40      0.32      0.36      1555
#            5       0.73      0.90      0.81      3876
#
#     accuracy                           0.62      7046
#    macro avg       0.45      0.34      0.35      7046
# weighted avg       0.57      0.62      0.58      7046
